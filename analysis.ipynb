# %% [markdown]
# # Data Analysis
# Just to take a quick look at the distribution around the actual distance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1 ft
# Bi modal, strictly around 1.01 and 2.02 meters.

# %%
df = pd.read_csv('ftm_1ft_output_list.csv', header=None)
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # 2 ft
# Unimodal at 3.03 meters

# %%
df = pd.read_csv('ftm_2ft_output_list.csv', header=None)
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # 3 ft
